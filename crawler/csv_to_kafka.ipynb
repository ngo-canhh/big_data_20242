# %%
import pandas as pd
import json
import logging
import os
from kafka import KafkaProducer
from kafka.admin import KafkaAdminClient, NewTopic
from kafka.errors import KafkaError
import time

# --- Cấu hình Logging ---
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger(__name__)

# --- Cấu hình Kafka ---
KAFKA_BROKER_URL = os.getenv('KAFKA_BROKER_URL', 'localhost:9092')
KAFKA_TOPIC = 'football_players'

# --- File paths ---
INPUT_CSV = "Cleaned_Data.csv"  # Thay bằng đường dẫn tới file CSV của bạn
OUTPUT_CSV = "Filtered_Final_Data.csv"     # File CSV để lưu dữ liệu đã lọc

# --- Kiểm tra và tạo Kafka topic ---
def check_and_create_topic():
    try:
        admin_client = KafkaAdminClient(bootstrap_servers=[KAFKA_BROKER_URL])
        topic_list = admin_client.list_topics()
        if KAFKA_TOPIC not in topic_list:
            logger.info(f"Topic '{KAFKA_TOPIC}' does not exist. Creating...")
            new_topic = NewTopic(name=KAFKA_TOPIC, num_partitions=1, replication_factor=1)
            admin_client.create_topics(new_topics=[new_topic], validate_only=False)
            logger.info(f"Topic '{KAFKA_TOPIC}' created successfully.")
        else:
            logger.info(f"Topic '{KAFKA_TOPIC}' already exists.")
        admin_client.close()
    except Exception as e:
        logger.error(f"Error checking/creating topic: {e}")
        raise

# --- Hàm gửi dữ liệu vào Kafka (bất đồng bộ) ---
def on_send_success(record_metadata):
    pass

def on_send_error(excp):
    logger.error(f"ERROR sending message to Kafka: {excp}")

def send_to_kafka_async(producer, topic, data, max_retries=3):
    if not data or not producer:
        return False
    for attempt in range(max_retries):
        try:
            producer.send(topic, value=data).add_callback(on_send_success).add_errback(on_send_error)
            return True
        except Exception as e:
            logger.error(f"Attempt {attempt+1}/{max_retries} failed: {e}")
            if attempt < max_retries - 1:
                time.sleep(2 ** attempt)  # Exponential backoff
            else:
                logger.error(f"Failed to send after {max_retries} attempts.")
                return False

# --- Hàm lọc dữ liệu từ CSV ---
def filter_player_data(df):
    required_columns = [
        "player_id", "name", "player_club", "age", "position", "market_value",
        "nationality", "player_height", "strong_foot", "contract_value_time",
        "goalkeeper_or_not", "appearances", "PPG", "goals", "assists", "own_goals",
        "substitutions_on", "substitutions_off", "yellow_cards", "second_yellow_cards",
        "red_cards", "penalty_goals", "minutes_per_goal", "minutes_played",
        "goals_conceded", "clean_sheet", "crawl_timestamp"
    ]
    
    # Kiểm tra các cột bắt buộc có trong file CSV không
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        logger.error(f"Missing required columns in CSV: {missing_columns}")
        raise ValueError(f"CSV file must contain all required columns: {required_columns}")
    
    # Lọc dữ liệu
    filtered_df = df[
        (df['position'] != 'Goalkeeper') &                    # Loại bỏ thủ môn
        (df[required_columns].notna().all(axis=1)) &         # Loại bỏ hàng thiếu bất kỳ trường bắt buộc nào
        (df['strong_foot'].isin(['left', 'right', 'both']))  # Đảm bảo strong_foot hợp lệ
    ]
    
    # Kiểm tra các cột số không âm
    numeric_columns = [
        'age', 'market_value', 'player_height', 'appearances', 'PPG', 'goals',
        'assists', 'own_goals', 'substitutions_on', 'substitutions_off',
        'yellow_cards', 'second_yellow_cards', 'red_cards', 'penalty_goals',
        'minutes_per_goal', 'minutes_played', 'goals_conceded', 'clean_sheet', 'crawl_timestamp'
    ]
    for col in numeric_columns:
        if col in filtered_df.columns:
            filtered_df = filtered_df[
                (filtered_df[col].apply(lambda x: isinstance(x, (int, float)) and x >= 0))
            ]
    
    return filtered_df

# --- Hàm chính ---
def main():
    # Đọc file CSV
    try:
        df = pd.read_csv(INPUT_CSV, encoding='utf-8-sig')
        logger.info(f"Loaded {len(df)} player records from {INPUT_CSV}")
    except Exception as e:
        logger.error(f"Error reading CSV file {INPUT_CSV}: {e}")
        return
    
    # Lọc dữ liệu
    filtered_df = filter_player_data(df)
    logger.info(f"After filtering, {len(filtered_df)} player records remain")
    
    if filtered_df.empty:
        logger.error("No player data passed the filtering criteria. Exiting.")
        return
    
    # Kiểm tra và tạo Kafka topic
    check_and_create_topic()
    
    # Khởi tạo Kafka producer
    try:
        logger.info(f"Connecting to Kafka broker at {KAFKA_BROKER_URL}...")
        producer = KafkaProducer(
            bootstrap_servers=[KAFKA_BROKER_URL],
            value_serializer=lambda v: json.dumps(v, ensure_ascii=False).encode('utf-8'),
            retries=5,
            acks='all'
        )
        logger.info("Successfully connected to Kafka.")
    except Exception as e:
        logger.error(f"CRITICAL: Error connecting to Kafka: {e}")
        return
    
    # Biến đếm số lần gửi Kafka
    successful_sends_attempted = 0
    failed_prepares = 0
    
    try:
        # Xử lý từng cầu thủ
        for i, row in filtered_df.iterrows():
            player_data = row.to_dict()
            player_data['crawl_timestamp'] = int(time.time() * 1000)  # Thêm timestamp
            
            # Gửi dữ liệu vào Kafka
            if send_to_kafka_async(producer, KAFKA_TOPIC, player_data):
                successful_sends_attempted += 1
                logger.info(f"Successfully sent data for player ID {player_data['player_id']} to Kafka")
            else:
                failed_prepares += 1
                logger.error(f"Failed to send data for player ID {player_data['player_id']} to Kafka")
            
            # Lưu vào CSV sau mỗi 10 cầu thủ
            if (i + 1) % 10 == 0:
                filtered_df.iloc[:i+1].to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
                producer.flush()
                logger.info(f"Saved {i+1} players to {OUTPUT_CSV}")
    
    finally:
        logger.info("-" * 30)
        logger.info("Processing finished.")
        logger.info(f"Total Kafka send attempts prepared: {successful_sends_attempted}")
        logger.info(f"Total Kafka send preparation failures: {failed_prepares}")
        
        # Lưu dữ liệu lần cuối
        filtered_df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
        logger.info(f"Final filtered data saved to {OUTPUT_CSV}")
        
        # Flush và đóng producer
        if producer:
            logger.info("Flushing Kafka producer (waiting for pending messages)...")
            try:
                producer.flush(timeout=60)
                logger.info("Kafka producer flushed.")
            except Exception as flush_e:
                logger.error(f"ERROR during producer flush: {flush_e}")
            finally:
                logger.info("Closing Kafka producer.")
                producer.close()
        
        logger.info("Script finished.")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-26 17:24:49,337 - INFO - Loaded 3363 player records from Cleaned_Data.csv
# 2025-05-26 17:24:49,414 - INFO - After filtering, 3363 player records remain
# 2025-05-26 17:24:49,421 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 17:24:49,603 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# 2025-05-26 17:24:49,605 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 17:24:49,676 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 17:24:49,678 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 17:24:49,678 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 17:24:49,717 - INFO - Topic 'football_players' does not exist. Creating...
# 2025-05-26 17:24:50,723 - INFO - Topic 'football_players' created successfully.
# 2025-05-26 17:24:50,725 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 17:24:50,727 - INFO - Connecting to Kafka broker at localhost:9092...
# 2025-05-26 17:24:50,729 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 17:24:50,741 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# 2025-05-26 17:24:50,742 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 17:24:50,748 - INFO - Successfully connected to Kafka.
# 2025-05-26 17:24:50,870 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 17:24:50,885 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 17:24:50,885 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 17:24:50,999 - INFO - Successfully sent data for player ID 258004 to Kafka
# 2025-05-26 17:24:51,005 - INFO - Successfully sent data for player ID 763079 to Kafka
# 2025-05-26 17:24:51,012 - INFO - Successfully sent data for player ID 177476 to Kafka
# 2025-05-26 17:24:51,014 - INFO - Successfully sent data for player ID 284730 to Kafka
# 2025-05-26 17:24:51,017 - INFO - Successfully sent data for player ID 186590 to Kafka
# 2025-05-26 17:24:51,020 - INFO - Successfully sent data for player ID 1005575 to Kafka
# 2025-05-26 17:24:51,023 - INFO - Successfully sent data for player ID 475959 to Kafka
# 2025-05-26 17:24:51,028 - INFO - Successfully sent data for player ID 357565 to Kafka
# 2025-05-26 17:24:51,030 - INFO - Successfully sent data for player ID 466805 to Kafka
# 2025-05-26 17:24:51,031 - INFO - Successfully sent data for player ID 53622 to Kafka
# 2025-05-26 17:24:51,539 - INFO - Saved 10 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:51,542 - INFO - Successfully sent data for player ID 241641 to Kafka
# 2025-05-26 17:24:51,545 - INFO - Successfully sent data for player ID 88755 to Kafka
# 2025-05-26 17:24:51,547 - INFO - Successfully sent data for player ID 743413 to Kafka
# 2025-05-26 17:24:51,550 - INFO - Successfully sent data for player ID 486049 to Kafka
# 2025-05-26 17:24:51,552 - INFO - Successfully sent data for player ID 203460 to Kafka
# 2025-05-26 17:24:51,556 - INFO - Successfully sent data for player ID 406635 to Kafka
# 2025-05-26 17:24:51,556 - INFO - Successfully sent data for player ID 743591 to Kafka
# 2025-05-26 17:24:51,556 - INFO - Successfully sent data for player ID 661207 to Kafka
# 2025-05-26 17:24:51,556 - INFO - Successfully sent data for player ID 418560 to Kafka
# 2025-05-26 17:24:51,556 - INFO - Successfully sent data for player ID 435338 to Kafka
# 2025-05-26 17:24:51,636 - INFO - Saved 20 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:51,638 - INFO - Successfully sent data for player ID 425918 to Kafka
# 2025-05-26 17:24:51,639 - INFO - Successfully sent data for player ID 502821 to Kafka
# 2025-05-26 17:24:51,646 - INFO - Successfully sent data for player ID 203853 to Kafka
# 2025-05-26 17:24:51,649 - INFO - Successfully sent data for player ID 300716 to Kafka
# 2025-05-26 17:24:51,649 - INFO - Successfully sent data for player ID 335721 to Kafka
# 2025-05-26 17:24:51,655 - INFO - Successfully sent data for player ID 331560 to Kafka
# 2025-05-26 17:24:51,657 - INFO - Successfully sent data for player ID 230784 to Kafka
# 2025-05-26 17:24:51,661 - INFO - Successfully sent data for player ID 357662 to Kafka
# 2025-05-26 17:24:51,661 - INFO - Successfully sent data for player ID 338424 to Kafka
# 2025-05-26 17:24:51,666 - INFO - Successfully sent data for player ID 655488 to Kafka
# 2025-05-26 17:24:51,695 - INFO - Saved 30 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:51,698 - INFO - Successfully sent data for player ID 144028 to Kafka
# 2025-05-26 17:24:51,701 - INFO - Successfully sent data for player ID 433177 to Kafka
# 2025-05-26 17:24:51,704 - INFO - Successfully sent data for player ID 890719 to Kafka
# 2025-05-26 17:24:51,715 - INFO - Successfully sent data for player ID 309400 to Kafka
# 2025-05-26 17:24:51,717 - INFO - Successfully sent data for player ID 363205 to Kafka
# 2025-05-26 17:24:51,719 - INFO - Successfully sent data for player ID 256178 to Kafka
# 2025-05-26 17:24:51,725 - INFO - Successfully sent data for player ID 632349 to Kafka
# 2025-05-26 17:24:51,728 - INFO - Successfully sent data for player ID 338070 to Kafka
# 2025-05-26 17:24:51,730 - INFO - Successfully sent data for player ID 234803 to Kafka
# 2025-05-26 17:24:51,733 - INFO - Successfully sent data for player ID 314353 to Kafka
# 2025-05-26 17:24:51,762 - INFO - Saved 40 players to Filtered_Final_Data.csv
# 2025-05-26 17:24
# 2025-05-26 17:24:53,117 - INFO - Successfully sent data for player ID 469050 to Kafka
# 2025-05-26 17:24:53,118 - INFO - Successfully sent data for player ID 541231 to Kafka
# 2025-05-26 17:24:53,119 - INFO - Successfully sent data for player ID 709767 to Kafka
# 2025-05-26 17:24:53,120 - INFO - Successfully sent data for player ID 644401 to Kafka
# 2025-05-26 17:24:53,154 - INFO - Saved 220 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,156 - INFO - Successfully sent data for player ID 339556 to Kafka
# 2025-05-26 17:24:53,160 - INFO - Successfully sent data for player ID 823486 to Kafka
# 2025-05-26 17:24:53,164 - INFO - Successfully sent data for player ID 270171 to Kafka
# 2025-05-26 17:24:53,168 - INFO - Successfully sent data for player ID 148367 to Kafka
# 2025-05-26 17:24:53,168 - INFO - Successfully sent data for player ID 1141628 to Kafka
# 2025-05-26 17:24:53,174 - INFO - Successfully sent data for player ID 319859 to Kafka
# 2025-05-26 17:24:53,179 - INFO - Successfully sent data for player ID 717411 to Kafka
# 2025-05-26 17:24:53,179 - INFO - Successfully sent data for player ID 470596 to Kafka
# 2025-05-26 17:24:53,186 - INFO - Successfully sent data for player ID 540941 to Kafka
# 2025-05-26 17:24:53,187 - INFO - Successfully sent data for player ID 559263 to Kafka
# 2025-05-26 17:24:53,222 - INFO - Saved 230 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,224 - INFO - Successfully sent data for player ID 1086375 to Kafka
# 2025-05-26 17:24:53,229 - INFO - Successfully sent data for player ID 413039 to Kafka
# 2025-05-26 17:24:53,232 - INFO - Successfully sent data for player ID 739443 to Kafka
# 2025-05-26 17:24:53,233 - INFO - Successfully sent data for player ID 606718 to Kafka
# 2025-05-26 17:24:53,239 - INFO - Successfully sent data for player ID 438001 to Kafka
# 2025-05-26 17:24:53,239 - INFO - Successfully sent data for player ID 716276 to Kafka
# 2025-05-26 17:24:53,245 - INFO - Successfully sent data for player ID 955253 to Kafka
# 2025-05-26 17:24:53,246 - INFO - Successfully sent data for player ID 121477 to Kafka
# 2025-05-26 17:24:53,248 - INFO - Successfully sent data for player ID 578391 to Kafka
# 2025-05-26 17:24:53,249 - INFO - Successfully sent data for player ID 1193867 to Kafka
# 2025-05-26 17:24:53,270 - INFO - Saved 240 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,272 - INFO - Successfully sent data for player ID 171679 to Kafka
# 2025-05-26 17:24:53,278 - INFO - Successfully sent data for player ID 735570 to Kafka
# 2025-05-26 17:24:53,281 - INFO - Successfully sent data for player ID 450050 to Kafka
# 2025-05-26 17:24:53,283 - INFO - Successfully sent data for player ID 433183 to Kafka
# 2025-05-26 17:24:53,284 - INFO - Successfully sent data for player ID 667121 to Kafka
# 2025-05-26 17:24:53,290 - INFO - Successfully sent data for player ID 225122 to Kafka
# 2025-05-26 17:24:53,296 - INFO - Successfully sent data for player ID 742451 to Kafka
# 2025-05-26 17:24:53,297 - INFO - Successfully sent data for player ID 74230 to Kafka
# 2025-05-26 17:24:53,302 - INFO - Successfully sent data for player ID 517894 to Kafka
# 2025-05-26 17:24:53,307 - INFO - Successfully sent data for player ID 429983 to Kafka
# 2025-05-26 17:24:53,325 - INFO - Saved 250 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,327 - INFO - Successfully sent data for player ID 292246 to Kafka
# 2025-05-26 17:24:53,328 - INFO - Successfully sent data for player ID 863741 to Kafka
# 2025-05-26 17:24:53,334 - INFO - Successfully sent data for player ID 661053 to Kafka
# 2025-05-26 17:24:53,335 - INFO - Successfully sent data for player ID 173504 to Kafka
# 2025-05-26 17:24:53,341 - INFO - Successfully sent data for player ID 118534 to Kafka
# 2025-05-26 17:24:53,346 - INFO - Successfully sent data for player ID 404842 to Kafka
# 2025-05-26 17:24:53,349 - INFO - Successfully sent data for player ID 424015 to Kafka
# 2025-05-26 17:24:53,350 - INFO - Successfully sent data for player ID 68390 to Kafka
# 2025-05-26 17:24:53,358 - INFO - Successfully sent data for player ID 505219 to Kafka
# 2025-05-26 17:24:53,361 - INFO - Successfully sent data for player ID 126665 to Kafka
# 2025-05-26 17:24:53,382 - INFO - Saved 260 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,384 - INFO - Successfully sent data for player ID 748319 to Kafka
# 2025-05-26 17:24:53,388 - INFO - Successfully sent data for player ID 696589 to Kafka
# 2025-05-26 17:24:53,393 - INFO - Successfully sent data for player ID 584769 to Kafka
# 2025-05-26 17:24:53,396 - INFO - Successfully sent data for player ID 417346 to Kafka
# 2025-05-26 17:24:53,400 - INFO - Successfully sent data for player ID 306024 to Kafka
# 2025-05-26 17:24:53,403 - INFO - Successfully sent data for player ID 595809 to Kafka
# 2025-05-26 17:24:53,408 - INFO - Successfully sent data for player ID 670688 to Kafka
# 2025-05-26 17:24:53,413 - INFO - Successfully sent data for player ID 260827 to Kafka
# 2025-05-26 17:24:53,414 - INFO - Successfully sent data for player ID 461883 to Kafka
# 2025-05-26 17:24:53,415 - INFO - Successfully sent data for player ID 272622 to Kafka
# 2025-05-26 17:24:53,443 - INFO - Saved 270 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,445 - INFO - Successfully sent data for player ID 494880 to Kafka
# 2025-05-26 17:24:53,446 - INFO - Successfully sent data for player ID 349701 to Kafka
# 2025-05-26 17:24:53,446 - INFO - Successfully sent data for player ID 392775 to Kafka
# 2025-05-26 17:24:53,452 - INFO - Successfully sent data for player ID 333014 to Kafka
# 2025-05-26 17:24:53,459 - INFO - Successfully sent data for player ID 245056 to Kafka
# 2025-05-26 17:24:53,461 - INFO - Successfully sent data for player ID 226973 to Kafka
# 2025-05-26 17:24:53,467 - INFO - Successfully sent data for player ID 123275 to Kafka
# 2025-05-26 17:24:53,468 - INFO - Successfully sent data for player ID 392765 to Kafka
# 2025-05-26 17:24:53,470 - INFO - Successfully sent data for player ID 242631 to Kafka
# 2025-05-26 17:24:53,472 - INFO - Successfully sent data for player ID 203394 to Kafka
# 2025-05-26 17:24:53,535 - INFO - Saved 280 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,538 - INFO - Successfully sent data for player ID 340325 to Kafka
# 2025-05-26 17:24:53,543 - INFO - Successfully sent data for player ID 279455 to Kafka
# 2025-05-26 17:24:53,545 - INFO - Successfully sent data for player ID 204103 to Kafka
# 2025-05-26 17:24:53,547 - INFO - Successfully sent data for player ID 206040 to Kafka
# 2025-05-26 17:24:53,549 - INFO - Successfully sent data for player ID 525287 to Kafka
# 2025-05-26 17:24:53,553 - INFO - Successfully sent data for player ID 401320 to Kafka
# 2025-05-26 17:24:53,554 - INFO - Successfully sent data for player ID 343475 to Kafka
# 2025-05-26 17:24:53,556 - INFO - Successfully sent data for player ID 255788 to Kafka
# 2025-05-26 17:24:53,558 - INFO - Successfully sent data for player ID 596446 to Kafka
# 2025-05-26 17:24:53,560 - INFO - Successfully sent data for player ID 146509 to Kafka
# 2025-05-26 17:24:53,587 - INFO - Saved 290 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,589 - INFO - Successfully sent data for player ID 468002 to Kafka
# 2025-05-26 17:24:53,592 - INFO - Successfully sent data for player ID 342046 to Kafka
# 2025-05-26 17:24:53,597 - INFO - Successfully sent data for player ID 468066 to Kafka
# 2025-05-26 17:24:53,601 - INFO - Successfully sent data for player ID 458178 to Kafka
# 2025-05-26 17:24:53,603 - INFO - Successfully sent data for player ID 123551 to Kafka
# 2025-05-26 17:24:53,606 - INFO - Successfully sent data for player ID 181687 to Kafka
# 2025-05-26 17:24:53,612 - INFO - Successfully sent data for player ID 660867 to Kafka
# 2025-05-26 17:24:53,615 - INFO - Successfully sent data for player ID 741238 to Kafka
# 2025-05-26 17:24:53,621 - INFO - Successfully sent data for player ID 292139 to Kafka
# 2025-05-26 17:24:53,626 - INFO - Successfully sent data for player ID 665390 to Kafka
# 2025-05-26 17:24:53,643 - INFO - Saved 300 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,644 - INFO - Successfully sent data for player ID 344009 to Kafka
# 2025-05-26 17:24:53,648 - INFO - Successfully sent data for player ID 392591 to Kafka
# 2025-05-26 17:24:53,650 - INFO - Successfully sent data for player ID 255731 to Kafka
# 2025-05-26 17:24:53,655 - INFO - Successfully sent data for player ID 349503 to Kafka
# 2025-05-26 17:24:53,662 - INFO - Successfully sent data for player ID 420808 to Kafka
# 2025-05-26 17:24:53,666 - INFO - Successfully sent data for player ID 503977 to Kafka
# 2025-05-26 17:24:53,666 - INFO - Successfully sent data for player ID 467563 to Kafka
# 2025-05-26 17:24:53,673 - INFO - Successfully sent data for player ID 243028 to Kafka
# 2025-05-26 17:24:53,679 - INFO - Successfully sent data for player ID 503990 to Kafka
# 2025-05-26 17:24:53,682 - INFO - Successfully sent data for player ID 163744 to Kafka
# 2025-05-26 17:24:53,724 - INFO - Saved 310 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:53,729 - INFO - Successfully sent data for player ID 986298 to Kafka
# 2025-05-26 17:24:53,734 - INFO - Successfully sent data for player ID 262300 to Kafka
# 2025-05-26 17:24:53,738 - INFO - Successfully sent data for player ID 341051 to Kafka
# 2025-05-26 17:24:53,744 - INFO - Successfully sent data for player ID 405385 to Kafka
# 2025-05-26 17:24:53,749 - INFO - Successfully sent data for player ID 324223 to Kafka
# 2025-05-26 17:24:53,753 - INFO - Successfully sent data for player ID 711999 to Kafka
# 2025-05-26 17:24:53,755 - INFO - Successfully sent data for player ID 506189 to Kafka
# 2025-05-26 17:24:53,759 - INFO - Successfully sent data for player ID 468198 to Kafka
# 2025-05-26 17:24:53,761 - INFO - Successfully sent data for player ID 43530 to Kafka
# 2025-05-26 17:24:53,763 - INFO - Successfully sent data for player ID 746695 to Kafka
# 2025-05-26 17:24:53,799 - INFO - Saved 320 players to Filtered_Final_Data.csv
# 2025-05-26 17:24
# 2025-05-26 17:24:54,859 - INFO - Successfully sent data for player ID 638741 to Kafka
# 2025-05-26 17:24:54,859 - INFO - Successfully sent data for player ID 879768 to Kafka
# 2025-05-26 17:24:54,864 - INFO - Successfully sent data for player ID 186924 to Kafka
# 2025-05-26 17:24:54,865 - INFO - Successfully sent data for player ID 746357 to Kafka
# 2025-05-26 17:24:54,868 - INFO - Successfully sent data for player ID 581681 to Kafka
# 2025-05-26 17:24:54,911 - INFO - Saved 460 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:54,913 - INFO - Successfully sent data for player ID 729940 to Kafka
# 2025-05-26 17:24:54,916 - INFO - Successfully sent data for player ID 476237 to Kafka
# 2025-05-26 17:24:54,918 - INFO - Successfully sent data for player ID 473080 to Kafka
# 2025-05-26 17:24:54,921 - INFO - Successfully sent data for player ID 535834 to Kafka
# 2025-05-26 17:24:54,925 - INFO - Successfully sent data for player ID 351738 to Kafka
# 2025-05-26 17:24:54,929 - INFO - Successfully sent data for player ID 169416 to Kafka
# 2025-05-26 17:24:54,932 - INFO - Successfully sent data for player ID 258216 to Kafka
# 2025-05-26 17:24:54,936 - INFO - Successfully sent data for player ID 487417 to Kafka
# 2025-05-26 17:24:54,939 - INFO - Successfully sent data for player ID 857079 to Kafka
# 2025-05-26 17:24:54,945 - INFO - Successfully sent data for player ID 696764 to Kafka
# 2025-05-26 17:24:54,995 - INFO - Saved 470 players to Filtered_Final_Data.csv
# 2025-05-26 17:24:54,997 - INFO - Successfully sent data for player ID 503980 to Kafka
# 2025-05-26 17:24:54,999 - INFO - Successfully sent data for player ID 874080 to Kafka
# 2025-05-26 17:24:55,002 - INFO - Successfully sent data for player ID 647395 to Kafka
# 2025-05-26 17:24:55,005 - INFO - Successfully sent data for player ID 467599 to Kafka
# 2025-05-26 17:24:55,016 - INFO - Successfully sent data for player ID 859951 to Kafka
# 2025-05-26 17:24:55,019 - INFO - Successfully sent data for player ID 128904 to Kafka
# 2025-05-26 17:24:55,021 - INFO - Successfully sent data for player ID 154219 to Kafka
# 2025-05-26 17:24:55,024 - INFO - Successfully sent data for player ID 85706 to Kafka
# 2025-05-26 17:24:55,027 - INFO - Successfully sent data for player ID 851991 to Kafka
# 2025-05-26 17:24:55,030 - INFO - Successfully sent data for player ID 412953 to Kafka
# ...
# 2025-05-26 17:25:30,900 - INFO - Successfully sent data for player ID 212863 to Kafka
# 2025-05-26 17:25:30,906 - INFO - Successfully sent data for player ID 440737 to Kafka
# 2025-05-26 17:25:30,907 - INFO - Successfully sent data for player ID 646747 to Kafka
# 2025-05-26 17:25:30,913 - INFO - Successfully sent data for player ID 527838 to Kafka
# 2025-05-26 17:25:30,918 - INFO - Successfully sent data for player ID 184767 to Kafka
# 2025-05-26 17:25:30,920 - INFO - Successfully sent data for player ID 203516 to Kafka
# 2025-05-26 17:25:30,924 - INFO - Successfully sent data for player ID 581674 to Kafka
# 2025-05-26 17:25:30,935 - INFO - Successfully sent data for player ID 590687 to Kafka
# 2025-05-26 17:25:31,138 - INFO - Saved 3210 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:31,140 - INFO - Successfully sent data for player ID 187673 to Kafka
# 2025-05-26 17:25:31,626 - INFO - Successfully sent data for player ID 513441 to Kafka
# 2025-05-26 17:25:31,629 - INFO - Successfully sent data for player ID 581701 to Kafka
# 2025-05-26 17:25:31,633 - INFO - Successfully sent data for player ID 537763 to Kafka
# 2025-05-26 17:25:31,636 - INFO - Successfully sent data for player ID 260230 to Kafka
# 2025-05-26 17:25:31,641 - INFO - Successfully sent data for player ID 400104 to Kafka
# 2025-05-26 17:25:31,644 - INFO - Successfully sent data for player ID 595357 to Kafka
# 2025-05-26 17:25:31,651 - INFO - Successfully sent data for player ID 67550 to Kafka
# 2025-05-26 17:25:31,832 - INFO - Saved 3250 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:31,833 - INFO - Successfully sent data for player ID 625653 to Kafka
# 2025-05-26 17:25:31,839 - INFO - Successfully sent data for player ID 353018 to Kafka
# 2025-05-26 17:25:31,841 - INFO - Successfully sent data for player ID 350208 to Kafka
# 2025-05-26 17:25:31,844 - INFO - Successfully sent data for player ID 628301 to Kafka
# 2025-05-26 17:25:31,854 - INFO - Successfully sent data for player ID 396334 to Kafka
# 2025-05-26 17:25:31,862 - INFO - Successfully sent data for player ID 524197 to Kafka
# 2025-05-26 17:25:31,865 - INFO - Successfully sent data for player ID 278651 to Kafka
# 2025-05-26 17:25:31,880 - INFO - Successfully sent data for player ID 605466 to Kafka
# 2025-05-26 17:25:31,883 - INFO - Successfully sent data for player ID 81988 to Kafka
# 2025-05-26 17:25:31,888 - INFO - Successfully sent data for player ID 1137080 to Kafka
# 2025-05-26 17:25:32,022 - INFO - Saved 3260 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,024 - INFO - Successfully sent data for player ID 353034 to Kafka
# 2025-05-26 17:25:32,029 - INFO - Successfully sent data for player ID 611816 to Kafka
# 2025-05-26 17:25:32,031 - INFO - Successfully sent data for player ID 199341 to Kafka
# 2025-05-26 17:25:32,037 - INFO - Successfully sent data for player ID 265289 to Kafka
# 2025-05-26 17:25:32,039 - INFO - Successfully sent data for player ID 765467 to Kafka
# 2025-05-26 17:25:32,039 - INFO - Successfully sent data for player ID 146258 to Kafka
# 2025-05-26 17:25:32,046 - INFO - Successfully sent data for player ID 162063 to Kafka
# 2025-05-26 17:25:32,055 - INFO - Successfully sent data for player ID 160285 to Kafka
# 2025-05-26 17:25:32,056 - INFO - Successfully sent data for player ID 408472 to Kafka
# 2025-05-26 17:25:32,062 - INFO - Successfully sent data for player ID 208022 to Kafka
# 2025-05-26 17:25:32,174 - INFO - Saved 3270 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,176 - INFO - Successfully sent data for player ID 540659 to Kafka
# 2025-05-26 17:25:32,178 - INFO - Successfully sent data for player ID 352223 to Kafka
# 2025-05-26 17:25:32,181 - INFO - Successfully sent data for player ID 536619 to Kafka
# 2025-05-26 17:25:32,187 - INFO - Successfully sent data for player ID 255729 to Kafka
# 2025-05-26 17:25:32,191 - INFO - Successfully sent data for player ID 461959 to Kafka
# 2025-05-26 17:25:32,193 - INFO - Successfully sent data for player ID 633111 to Kafka
# 2025-05-26 17:25:32,198 - INFO - Successfully sent data for player ID 776579 to Kafka
# 2025-05-26 17:25:32,207 - INFO - Successfully sent data for player ID 598611 to Kafka
# 2025-05-26 17:25:32,210 - INFO - Successfully sent data for player ID 827950 to Kafka
# 2025-05-26 17:25:32,214 - INFO - Successfully sent data for player ID 281773 to Kafka
# 2025-05-26 17:25:32,455 - INFO - Saved 3280 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,463 - INFO - Successfully sent data for player ID 410696 to Kafka
# 2025-05-26 17:25:32,466 - INFO - Successfully sent data for player ID 465317 to Kafka
# 2025-05-26 17:25:32,471 - INFO - Successfully sent data for player ID 461619 to Kafka
# 2025-05-26 17:25:32,473 - INFO - Successfully sent data for player ID 282724 to Kafka
# 2025-05-26 17:25:32,477 - INFO - Successfully sent data for player ID 820375 to Kafka
# 2025-05-26 17:25:32,477 - INFO - Successfully sent data for player ID 290533 to Kafka
# 2025-05-26 17:25:32,497 - INFO - Successfully sent data for player ID 524008 to Kafka
# 2025-05-26 17:25:32,506 - INFO - Successfully sent data for player ID 1270449 to Kafka
# 2025-05-26 17:25:32,536 - INFO - Successfully sent data for player ID 435500 to Kafka
# 2025-05-26 17:25:32,540 - INFO - Successfully sent data for player ID 531062 to Kafka
# 2025-05-26 17:25:32,628 - INFO - Saved 3290 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,630 - INFO - Successfully sent data for player ID 71834 to Kafka
# 2025-05-26 17:25:32,632 - INFO - Successfully sent data for player ID 197576 to Kafka
# 2025-05-26 17:25:32,637 - INFO - Successfully sent data for player ID 404688 to Kafka
# 2025-05-26 17:25:32,639 - INFO - Successfully sent data for player ID 345654 to Kafka
# 2025-05-26 17:25:32,643 - INFO - Successfully sent data for player ID 610461 to Kafka
# 2025-05-26 17:25:32,646 - INFO - Successfully sent data for player ID 963613 to Kafka
# 2025-05-26 17:25:32,649 - INFO - Successfully sent data for player ID 726030 to Kafka
# 2025-05-26 17:25:32,653 - INFO - Successfully sent data for player ID 51510 to Kafka
# 2025-05-26 17:25:32,658 - INFO - Successfully sent data for player ID 114060 to Kafka
# 2025-05-26 17:25:32,660 - INFO - Successfully sent data for player ID 892685 to Kafka
# 2025-05-26 17:25:32,782 - INFO - Saved 3300 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,785 - INFO - Successfully sent data for player ID 354697 to Kafka
# 2025-05-26 17:25:32,789 - INFO - Successfully sent data for player ID 531121 to Kafka
# 2025-05-26 17:25:32,792 - INFO - Successfully sent data for player ID 834485 to Kafka
# 2025-05-26 17:25:32,795 - INFO - Successfully sent data for player ID 158791 to Kafka
# 2025-05-26 17:25:32,797 - INFO - Successfully sent data for player ID 521455 to Kafka
# 2025-05-26 17:25:32,803 - INFO - Successfully sent data for player ID 591957 to Kafka
# 2025-05-26 17:25:32,806 - INFO - Successfully sent data for player ID 834487 to Kafka
# 2025-05-26 17:25:32,810 - INFO - Successfully sent data for player ID 711374 to Kafka
# 2025-05-26 17:25:32,812 - INFO - Successfully sent data for player ID 603696 to Kafka
# 2025-05-26 17:25:32,815 - INFO - Successfully sent data for player ID 627287 to Kafka
# 2025-05-26 17:25:32,920 - INFO - Saved 3310 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:32,924 - INFO - Successfully sent data for player ID 895326 to Kafka
# 2025-05-26 17:25:32,926 - INFO - Successfully sent data for player ID 710679 to Kafka
# 2025-05-26 17:25:32,929 - INFO - Successfully sent data for player ID 1064699 to Kafka
# 2025-05-26 17:25:32,934 - INFO - Successfully sent data for player ID 625658 to Kafka
# 2025-05-26 17:25:32,938 - INFO - Successfully sent data for player ID 711377 to Kafka
# 2025-05-26 17:25:32,942 - INFO - Successfully sent data for player ID 1064871 to Kafka
# 2025-05-26 17:25:32,946 - INFO - Successfully sent data for player ID 610622 to Kafka
# 2025-05-26 17:25:32,952 - INFO - Successfully sent data for player ID 1060456 to Kafka
# 2025-05-26 17:25:32,957 - INFO - Successfully sent data for player ID 78818 to Kafka
# 2025-05-26 17:25:32,960 - INFO - Successfully sent data for player ID 277500 to Kafka
# 2025-05-26 17:25:33,154 - INFO - Saved 3320 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:33,156 - INFO - Successfully sent data for player ID 96539 to Kafka
# 2025-05-26 17:25:33,156 - INFO - Successfully sent data for player ID 406773 to Kafka
# 2025-05-26 17:25:33,196 - INFO - Successfully sent data for player ID 590690 to Kafka
# 2025-05-26 17:25:33,240 - INFO - Successfully sent data for player ID 442816 to Kafka
# 2025-05-26 17:25:33,252 - INFO - Successfully sent data for player ID 784719 to Kafka
# 2025-05-26 17:25:33,256 - INFO - Successfully sent data for player ID 355501 to Kafka
# 2025-05-26 17:25:33,261 - INFO - Successfully sent data for player ID 158795 to Kafka
# 2025-05-26 17:25:33,264 - INFO - Successfully sent data for player ID 263856 to Kafka
# 2025-05-26 17:25:33,270 - INFO - Successfully sent data for player ID 199131 to Kafka
# 2025-05-26 17:25:33,274 - INFO - Successfully sent data for player ID 932349 to Kafka
# 2025-05-26 17:25:33,495 - INFO - Saved 3330 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:33,497 - INFO - Successfully sent data for player ID 162079 to Kafka
# 2025-05-26 17:25:33,502 - INFO - Successfully sent data for player ID 706138 to Kafka
# 2025-05-26 17:25:33,506 - INFO - Successfully sent data for player ID 566965 to Kafka
# 2025-05-26 17:25:33,509 - INFO - Successfully sent data for player ID 537375 to Kafka
# 2025-05-26 17:25:33,510 - INFO - Successfully sent data for player ID 412046 to Kafka
# 2025-05-26 17:25:33,510 - INFO - Successfully sent data for player ID 606720 to Kafka
# 2025-05-26 17:25:33,520 - INFO - Successfully sent data for player ID 337070 to Kafka
# 2025-05-26 17:25:33,524 - INFO - Successfully sent data for player ID 715679 to Kafka
# 2025-05-26 17:25:33,527 - INFO - Successfully sent data for player ID 156817 to Kafka
# 2025-05-26 17:25:33,536 - INFO - Successfully sent data for player ID 500191 to Kafka
# 2025-05-26 17:25:33,633 - INFO - Saved 3340 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:33,641 - INFO - Successfully sent data for player ID 628923 to Kafka
# 2025-05-26 17:25:33,643 - INFO - Successfully sent data for player ID 65318 to Kafka
# 2025-05-26 17:25:33,645 - INFO - Successfully sent data for player ID 560107 to Kafka
# 2025-05-26 17:25:33,645 - INFO - Successfully sent data for player ID 652331 to Kafka
# 2025-05-26 17:25:33,655 - INFO - Successfully sent data for player ID 336051 to Kafka
# 2025-05-26 17:25:33,656 - INFO - Successfully sent data for player ID 596899 to Kafka
# 2025-05-26 17:25:33,660 - INFO - Successfully sent data for player ID 568156 to Kafka
# 2025-05-26 17:25:33,665 - INFO - Successfully sent data for player ID 234866 to Kafka
# 2025-05-26 17:25:33,669 - INFO - Successfully sent data for player ID 689639 to Kafka
# 2025-05-26 17:25:33,671 - INFO - Successfully sent data for player ID 455349 to Kafka
# 2025-05-26 17:25:33,825 - INFO - Saved 3350 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:33,827 - INFO - Successfully sent data for player ID 149231 to Kafka
# 2025-05-26 17:25:33,828 - INFO - Successfully sent data for player ID 821820 to Kafka
# 2025-05-26 17:25:33,833 - INFO - Successfully sent data for player ID 242882 to Kafka
# 2025-05-26 17:25:33,833 - INFO - Successfully sent data for player ID 487180 to Kafka
# 2025-05-26 17:25:33,840 - INFO - Successfully sent data for player ID 630998 to Kafka
# 2025-05-26 17:25:33,840 - INFO - Successfully sent data for player ID 537767 to Kafka
# 2025-05-26 17:25:33,840 - INFO - Successfully sent data for player ID 412041 to Kafka
# 2025-05-26 17:25:33,840 - INFO - Successfully sent data for player ID 699233 to Kafka
# 2025-05-26 17:25:33,858 - INFO - Successfully sent data for player ID 148666 to Kafka
# 2025-05-26 17:25:33,865 - INFO - Successfully sent data for player ID 226006 to Kafka
# 2025-05-26 17:25:34,041 - INFO - Saved 3360 players to Filtered_Final_Data.csv
# 2025-05-26 17:25:34,054 - INFO - Successfully sent data for player ID 466806 to Kafka
# 2025-05-26 17:25:34,057 - INFO - Successfully sent data for player ID 396328 to Kafka
# 2025-05-26 17:25:34,068 - INFO - Successfully sent data for player ID 652329 to Kafka
# 2025-05-26 17:25:34,075 - INFO - ------------------------------
# 2025-05-26 17:25:34,076 - INFO - Processing finished.
# 2025-05-26 17:25:34,078 - INFO - Total Kafka send attempts prepared: 3363
# 2025-05-26 17:25:34,081 - INFO - Total Kafka send preparation failures: 0
# 2025-05-26 17:25:34,186 - INFO - Final filtered data saved to Filtered_Final_Data.csv
# 2025-05-26 17:25:34,187 - INFO - Flushing Kafka producer (waiting for pending messages)...
# 2025-05-26 17:25:34,189 - INFO - Kafka producer flushed.
# 2025-05-26 17:25:34,189 - INFO - Closing Kafka producer.
# 2025-05-26 17:25:34,191 - INFO - Closing the Kafka producer with 4294967.0 secs timeout.
# 2025-05-26 17:25:34,192 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 17:25:34,193 - INFO - Script finished.
